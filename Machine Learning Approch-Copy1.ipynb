# %% [markdown]
# # 1.Importing Dependencies

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\rakesh rout\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: numpy in c:\users\rakesh rout\anaconda3\lib\site-packages (from xgboost) (1.20.1)
# Requirement already satisfied: scipy in c:\users\rakesh rout\anaconda3\lib\site-packages (from xgboost) (1.6.2)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt
plt.style.use("bmh")
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("metadata.csv")

# %%
df.head()
# Out:
#           author_id      pratilipi_id category_name  reading_time  \
# 0 -3418949279741297  1025741862639304   translation             0
# 1 -2270332351871840  1377786215601277   translation           171
# 2 -2270332352037261  1377786215601962   translation            92
# 3 -2270332352521845  1377786215640994   translation             0
# 4 -2270332349665658  1377786215931338   translation            47
#
#             updated_at         published_at
# 0  2020-08-19 15:26:13  2016-09-30 10:37:04
# 1  2021-01-21 16:27:07  2018-06-11 13:17:48
# 2  2020-09-29 12:33:57  2018-06-12 04:19:12
# 3  2019-10-17 09:03:37  2019-09-26 14:58:53
# 4  2020-05-05 11:33:41  2018-11-25 12:28:23

# %%
df.shape
# Out:
# (954501, 6)

# %%
plt.figure(figsize=(16,8))
plt.title("reading_time")
plt.xlabel("updated_at")
plt.ylabel("reading_time")
plt.plot(df["reading_time"])
plt.show()

# %%
df = df[["reading_time"]]
df.head()
# Out:
#    reading_time
# 0             0
# 1           171
# 2            92
# 3             0
# 4            47

# %%
# Create a variable to predict "x" reading out into future
future_pratilipi = 25
# Create a new column (target) shifted "x" pratilipi/day up
df["Prediction"] = df[["reading_time"]].shift(-future_pratilipi)
df.tail()
# Out:
#         reading_time  Prediction
# 954496           304         NaN
# 954497           588         NaN
# 954498           359         NaN
# 954499           310         NaN
# 954500           534         NaN

# %%
# Create the feature dataset (X) and convert it to a numpy array and remove the last "x" rows/days
X = np.array(df.drop(["Prediction"],1))[:-future_pratilipi]
X
# Out:
# array([[  0],
#        [171],
#        [ 92],
#        ...,
#        [697],
#        [951],
#        [775]], dtype=int64)

# %%
# Create the target data set (y) convert it to numpy array and get all of the target values except the last 'x' rows
y = np.array(df["Prediction"])[:-future_pratilipi]
y
# Out:
# array([129.,  81., 691., ..., 359., 310., 534.])

# %% [markdown]
# # 2.Spliting the data

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %% [markdown]
# # 3.Scaling the data

# %%
from sklearn.preprocessing import StandardScaler # Scaling for linear Regression is not strictly required for better practice we are doing standardscaling
scaler = StandardScaler() #initialise to a variable for standard scaler
scaler.fit(X_train,y_train) #fitting the train datset.we dont fit test dataset as we are going to use the test dataset directly for evalution
X_train = scaler.transform(X_train) #transform of train data
X_test = scaler.transform(X_test) #transform of test data

# %% [markdown]
# # 4.Model

# %%
#Create the decision tree regressor model
tree = DecisionTreeRegressor().fit(X_train,y_train)
#Create the linear regression model
# lr = LinearRegression().fit(X_train, y_train)
#Create the random forest regression
rfr = RandomForestRegressor().fit(X_train, y_train)
#Create the knearest neighbor
neigh = KNeighborsRegressor(n_neighbors=2).fit(X_train, y_train)
#Create the xgb algorithm
for lr in [0.7]:
  xgb_model = xgb.XGBRegressor(learning_rate = lr, n_estimators=100, verbosity = 0) # initialise the model
  xgb_model.fit(X_train,y_train) #train the model

# %%
# Get the last "x" rows of the feature data set
X_future = df.drop(["Prediction"],1)[:-future_pratilipi]
X_future = X_future.tail(future_pratilipi)
X_future = np.array(X_future)
X_future
# Out:
# array([[ 557],
#        [ 705],
#        [ 308],
#        [ 282],
#        [ 246],
#        [ 236],
#        [ 371],
#        [ 594],
#        [ 577],
#        [ 454],
#        [ 816],
#        [ 591],
#        [1100],
#        [ 951],
#        [ 598],
#        [ 823],
#        [1511],
#        [ 878],
#        [ 824],
#        [ 698],
#        [ 734],
#        [ 892],
#        [ 697],
#        [ 951],
#        [ 775]], dtype=int64)

# %%
#Show the model predictions
Decision_tree_prediction = tree.predict(X_future)
print(Decision_tree_prediction)
# lr_prediction = lr.predict(X_future)
# print(lr_prediction)
RandomForest_prediction = rfr.predict(X_future)
print(RandomForest_prediction)
KNN_prediction = neigh.predict(X_future)
print(KNN_prediction)
xgboost_prediction = xgb_model.predict(X_future)
print(xgboost_prediction)
# Out:
# [95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95. 95.
#  95. 95. 95. 95. 95. 95. 95.]
# [148.03166667 148.03166667 148.03166667 148.03166667 148.03166667
#  148.03166667 148.03166667 148.03166667 148.03166667 148.03166667
#  148.03166667 148.03166667 148.03166667 148.03166667 148.03166667
#  148.03166667 148.03166667 148.03166667 148.03166667 148.03166667
#  148.03166667 148.03166667 148.03166667 148.03166667 148.03166667]
# [135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5
#  135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5 135.5
#  135.5]
# [134.30003 134.30003 134.30003 134.30003 134.30003 134.30003 134.30003
#  134.30003 134.30003 134.30003 134.30003 134.30003 134.30003 134.30003
#  134.30003 134.30003 134.30003 134.30003 134.30003 134.30003 134.30003
#  134.30003 134.30003 134.30003 134.30003]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor_predict = regressor.predict(X_future)

# %%
print(regressor_predict)
# Out:
# [25927.94153332 32723.63133168 14494.65261581 13300.8152188
#  11647.80959217 11188.64136255 17387.41246241 27626.86398291
#  26846.27799256 21198.50876824 37820.39868045 27489.11351402
#  50860.77640163 44019.16978031 27810.53127476 38141.81644119
#  69732.59063898 40667.24170409 38187.73326415 32402.21357095
#  34055.21919758 41310.07722556 32356.29674799 44019.16978031
#  35937.80893901]

# %%
## Visualize the data
prediction = Decision_tree_prediction

valid=df[X.shape[0]:]
valid["prediction"]=prediction
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel("Days")
plt.ylabel("Pratilipis-timing")
plt.plot(df["reading_time"])
plt.plot(valid[["reading_time","prediction"]])
plt.legend(["orig","Val","pred"])
plt.show()

# %%
prediction = RandomForest_prediction

valid=df[X.shape[0]:]
valid["prediction"]=prediction
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel("Days")
plt.ylabel("Pratilipis-timing")
plt.plot(df["reading_time"])
plt.plot(valid[["reading_time","prediction"]])
plt.legend(["orig","Val","pred"])
plt.show()

# %%
prediction = KNN_prediction

valid=df[X.shape[0]:]
valid["prediction"]=prediction
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel("Days")
plt.ylabel("Pratilipis-timing")
plt.plot(df["reading_time"])
plt.plot(valid[["reading_time","prediction"]])
plt.legend(["orig","Val","pred"])
plt.show()

# %%
prediction = xgboost_prediction

valid=df[X.shape[0]:]
valid["prediction"]=prediction
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel("Days")
plt.ylabel("Pratilipis-timing")
plt.plot(df["reading_time"])
plt.plot(valid[["reading_time","prediction"]])
plt.legend(["orig","Val","pred"])
plt.show()
